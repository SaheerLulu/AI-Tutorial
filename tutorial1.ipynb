# %%
print("first tutorial")
# Out:
# first tutorial

# %%
# 4x + 5
x=6

fx = 4*x + 5
fx
# Out:
# 29

# %%
def f(x):
    return 4*x + 5

# %%
f(5)
# Out:
# 25

# %%
#ax+b
import matplotlib.pyplot as plt

# %%
plt.plot(10,f(10),"o")

# %%
x = [1,2,4,5,0]

# %%
y =map(f,x)

# %%
y=list(y)

# %%
plt.plot(x,y)

# %%
import numpy as np
x = np.arange(-10,10,0.05)

# %%
y = f(x)

# %%
plt.plot(x,y)

# %%
f(0)
# Out:
# 5

# %%
# ax +b

# %%
a =1
b=1

# %%
def g(x,a=1,b=1):
    return a*x + b

# %%
y_pred = g(x)

# %%
plt.plot(x,y)
plt.plot(x,y_pred)

# %%
y[0]
# Out:
# -35.0

# %%
y_pred[0]
# Out:
# -9.0

# %%
y_pred =g(x,a=19,b=4)
loss = sum((y - y_pred)**2)/len(x)
loss
# Out:
# 7501.843750000193

# %%
sum(y)
